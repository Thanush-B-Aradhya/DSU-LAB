# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\DSU-AI\Documents\ENG24AM0306\Exp 01\Datasets\ai_workforce_displacement_global_2020_2026.csv')

sns.set(style="whitegrid")
plt.rcParams["figure.figsize"]=(8,5)

# %% [markdown]
# Basic

# %%
print("="*60)
print("FIRST 5 RECORDS")
print(df.head())

print("\nSHAPE :",df.shape)

print("\nDATA TYPES")
print(df.dtypes)

print("\nMISSING VALUES")
print(df.isnull().sum())

print("\nDUPLICATES :",df.duplicated().sum())

print("\nSUMMARY STATISTICS")
print(df.describe())

print("\nCATEGORICAL FEATURES")
print(df.describe(include='object'))

# Numerical Columns
num_cols=df.select_dtypes(include='number').columns
# Out:
# ...
# FIRST 5 RECORDS
#    record_id        country iso3_code         region income_group  year  \
# 0          1  United States       USA  North America  High Income  2020
# 1          2  United States       USA  North America  High Income  2020
# 2          3  United States       USA  North America  High Income  2020
# 3          4  United States       USA  North America  High Income  2020
# 4          5  United States       USA  North America  High Income  2020
#
#    quarter quarter_label             industry_sector  \
# 0        1       2020-Q1       Technology & Software
# 1        1       2020-Q1           Finance & Banking
# 2        1       2020-Q1  Healthcare & Life Sciences
# 3        1       2020-Q1    Manufacturing & Industry
# 4        1       2020-Q1         Retail & E-Commerce
#
#    sector_automation_risk_score  ...  pct_sector_workforce_new_roles_created  \
# 0                         0.382  ...                                  0.0348
# ...

# %% [markdown]
# Histogram

# %%
df[num_cols].hist(figsize=(16,12),bins=20)
plt.suptitle("1. Histogram of Numerical Features")
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 23 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   record_id                               20800 non-null  int64
#  1   country                                 20800 non-null  object
#  2   iso3_code                               20800 non-null  object
#  3   region                                  20800 non-null  object
#  4   income_group                            20800 non-null  object
#  5   year                                    20800 non-null  int64
#  6   quarter                                 20800 non-null  int64
#  7   quarter_label                           20800 non-null  object
#  8   industry_sector                         20800 non-null  object
#  9   sector_automation_risk_score            20800 non-null  float64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['record_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#           record_id          year       quarter  sector_automation_risk_score  \
# count  20800.000000  20800.000000  20800.000000                  20800.000000
# mean   10400.500000   2022.769231      2.423077                      0.537881
# std     6004.587135      1.887406      1.115411                      0.190345
# min        1.000000   2020.000000      1.000000                      0.151000
# 25%     5200.750000   2021.000000      1.000000                      0.379000
# 50%    10400.500000   2023.000000      2.000000                      0.580000
# 75%    15600.250000   2024.000000      3.000000                      0.698000
# max    20800.000000   2026.000000      4.000000                      0.855000
#
#        gdp_per_capita_usd  ai_adoption_index  pct_sector_workforce_displaced  \
# count        20800.000000       20800.000000                    20800.000000
# mean         21003.330769           0.692148                        0.056155
# ...

# %%
sns.histplot(df['sector_automation_risk_score']
# Out:
#   Cell In[23], line 1
#     sns.histplot(df['sector_automation_risk_score']
#                                                    ^
# _IncompleteInputError: incomplete input

# %%
sns.kdeplot(df['ai_adoption_index'])
# Out:
# <Axes: xlabel='ai_adoption_index', ylabel='Density'>

# %%
sns.histplot(
    df['ai_adoption_index'],
    kde=True
)
# Out:
# <Axes: xlabel='ai_adoption_index', ylabel='Count'>

# %% [markdown]
# BOX PLOTs

# %%
sns.boxplot(y=df['gdp_per_capita_usd'])
# Out:
# <Axes: ylabel='gdp_per_capita_usd'>

# %%
sns.boxplot(
    data=df,
    x='income_group',
    y='ai_adoption_index'
)
# Out:
# <Axes: xlabel='income_group', ylabel='ai_adoption_index'>

# %%
print(df.memory_usage(deep=True))
# Out:
# Index                                         132
# record_id                                  166400
# country                                   1175200
# iso3_code                                 1081600
# region                                    1215500
# income_group                              1342900
# year                                       166400
# quarter                                    166400
# quarter_label                             1164800
# industry_sector                           1472640
# sector_automation_risk_score               166400
# gdp_per_capita_usd                         166400
# ai_adoption_index                          166400
# pct_sector_workforce_displaced             166400
# pct_sector_workforce_new_roles_created     166400
# net_workforce_change_pct                   166400
# ai_cited_layoff_announcements              166400
# ai_skill_wage_premium_pct                  166400
# pct_workforce_female                       166400
# ...

# %%
sns.violinplot(
    data=df,
    x='income_group',
    y='ai_adoption_index'
)
# Out:
# <Axes: xlabel='income_group', ylabel='ai_adoption_index'>

# %%
sns.countplot(data=df, x='industry_sector')
# Out:
# <Axes: xlabel='industry_sector', ylabel='count'>

# %%
categories = ['ai_adoption_index', 'gdp_per_capita_usd', 'industry_sector', 'sector_automation_risk_score']
values = [15, 30, 45, 10]


plt.bar(categories, values, color='skyblue', width=0.6)
# Out:
# <BarContainer object of 4 artists>
